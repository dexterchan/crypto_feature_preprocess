# %%
import pandas as pd
import pyarrow.dataset as pqds
from pyarrow import fs
import pyarrow as pa
import math

# %%
data_path = "data/kraken.ETHUSD"
data_set_index = "dsindex"
begin_partition:int = 202201
end_partition:int = 202303
# Read parquet file from data_path as pyarrown dateset
dataset: pqds.dataset = pqds.dataset(
            data_path,
            format="parquet",
            partitioning="hive",
            filesystem=fs.LocalFileSystem(),
        )

criteria = (pqds.field(data_set_index) >= begin_partition) & (
            pqds.field(data_set_index) <= end_partition
        )
dt: pa.table = dataset.to_table(filter=criteria)
df: pd.DataFrame = dt.to_pandas()
#Make column timestamp as pandas datetime index
df.set_index("timestamp", inplace=True)
#convert timestamp ms to datetime
df.index = pd.to_datetime(df.index, unit="ms")
# Resample candlestick to 60 minutes in length
df = df.resample("15Min").agg({"open": "first", "high": "max", "low": "min", "close": "last", "volume": "sum"})
# Remove any rows with NaN values
df.dropna(inplace=True)

# %%
df.head()
# Out:
#                         open     high      low    close      volume
# timestamp
# 2022-01-01 00:00:00  3675.95  3702.03  3675.95  3692.80  217.362166
# 2022-01-01 00:15:00  3690.98  3698.61  3685.18  3695.60  146.046925
# 2022-01-01 00:30:00  3696.68  3713.95  3696.01  3713.95   56.123719
# 2022-01-01 00:45:00  3713.62  3725.00  3713.62  3723.33  138.238059
# 2022-01-01 01:00:00  3722.79  3725.00  3714.73  3725.00  196.826344

# %%
# Shift the close price to the prev row
df["prev_close"] = df["close"].shift(1)
df["price_change"] = df["close"] / df["prev_close"]
# calcualte log of price_change column
df["log_price_change"] = df["price_change"].apply(lambda x: math.log(x))

# %%
from preprocess_data.domains.indicators import calculate_log_price_change
log_price_change = calculate_log_price_change(df["close"])
df["log_price_change2"] = log_price_change

# %%
# Remove the first row
df = df.iloc[1:]
c = (df["log_price_change"] - df["log_price_change2"] < 0.00001)
#show any c = False
df[~c]
# Out:
# Empty DataFrame
# Columns: [open, high, low, close, volume, prev_close, price_change, log_price_change, log_price_change2]
# Index: []

# %%
#Plot histogram of log_price_change with 1000 bin and title with plotlib
df["log_price_change"].hist(bins=100).set_title("log_price_change")
# Out:
# Text(0.5, 1.0, 'log_price_change')

# %%
# Plot histogram of log_price_change with 1000 bin and fall under 99% percentile and title with plotlib
df["log_price_change"].hist(bins=100, range=(df["log_price_change"].quantile(0.0001), df["log_price_change"].quantile(0.9999))).set_title("log_price_change")
# Out:
# Text(0.5, 1.0, 'log_price_change')

# %%
math.exp(0.02)
# Out:
# 1.0202013400267558

# %%
df.tail(20)
# Out:
#                         open     high      low    close       volume  \
# timestamp
# 2023-03-31 19:00:00  1822.87  1824.67  1818.54  1822.68   173.620502
# 2023-03-31 19:15:00  1822.68  1824.02  1820.22  1823.20   132.567886
# 2023-03-31 19:30:00  1823.59  1830.84  1823.59  1827.16   133.567876
# 2023-03-31 19:45:00  1827.24  1830.26  1826.47  1829.42    35.556076
# 2023-03-31 20:00:00  1829.46  1829.47  1824.58  1825.18    24.639109
# 2023-03-31 20:15:00  1825.01  1825.01  1819.21  1820.97   253.731151
# 2023-03-31 20:30:00  1821.65  1825.22  1819.20  1824.12  1142.384228
# 2023-03-31 20:45:00  1823.55  1826.00  1815.01  1817.68   444.809374
# 2023-03-31 21:00:00  1817.79  1818.78  1815.26  1818.77   142.042158
# 2023-03-31 21:15:00  1819.38  1822.89  1818.86  1822.21   509.268684
# 2023-03-31 21:30:00  1822.22  1826.11  1822.21  1826.11    55.447566
# 2023-03-31 21:45:00  1826.11  1828.00  1822.70  1824.25    82.110962
# 2023-03-31 22:00:00  1824.24  1826.85  1822.51  1824.16   130.692372
# 2023-03-31 22:15:00  1824.12  1828.85  1824.12  1827.07   109.871368
# 2023-03-31 22:30:00  1827.07  1829.40  1825.52  1828.00   131.338310
# 2023-03-31 22:45:00  1828.04  1829.39  1827.31  1827.54    43.983706
# 2023-03-31 23:00:00  1827.55  1827.55  1826.00  1826.00    23.840174
# 2023-03-31 23:15:00  1826.01  1826.19  1826.00  1826.07    17.402913
# 2023-03-31 23:30:00  1826.02  1826.02  1822.68  1822.68    49.554413
# 2023-03-31 23:45:00  1822.68  1824.04  1821.75  1821.86    93.980501
#
#                      prev_close  price_change  log_price_change  \
# timestamp
# 2023-03-31 19:00:00     1822.86      0.999901         -0.000099
# 2023-03-31 19:15:00     1822.68      1.000285          0.000285
# 2023-03-31 19:30:00     1823.20      1.002172          0.002170
# 2023-03-31 19:45:00     1827.16      1.001237          0.001236
# 2023-03-31 20:00:00     1829.42      0.997682         -0.002320
# 2023-03-31 20:15:00     1825.18      0.997693         -0.002309
# 2023-03-31 20:30:00     1820.97      1.001730          0.001728
# 2023-03-31 20:45:00     1824.12      0.996470         -0.003537
# 2023-03-31 21:00:00     1817.68      1.000600          0.000599
# 2023-03-31 21:15:00     1818.77      1.001891          0.001890
# 2023-03-31 21:30:00     1822.21      1.002140          0.002138
# 2023-03-31 21:45:00     1826.11      0.998981         -0.001019
# 2023-03-31 22:00:00     1824.25      0.999951         -0.000049
# 2023-03-31 22:15:00     1824.16      1.001595          0.001594
# 2023-03-31 22:30:00     1827.07      1.000509          0.000509
# 2023-03-31 22:45:00     1828.00      0.999748         -0.000252
# 2023-03-31 23:00:00     1827.54      0.999157         -0.000843
# 2023-03-31 23:15:00     1826.00      1.000038          0.000038
# 2023-03-31 23:30:00     1826.07      0.998144         -0.001858
# 2023-03-31 23:45:00     1822.68      0.999550         -0.000450
#
#                      log_price_change2
# timestamp
# 2023-03-31 19:00:00          -0.000099
# 2023-03-31 19:15:00           0.000285
# 2023-03-31 19:30:00           0.002170
# 2023-03-31 19:45:00           0.001236
# 2023-03-31 20:00:00          -0.002320
# 2023-03-31 20:15:00          -0.002309
# 2023-03-31 20:30:00           0.001728
# 2023-03-31 20:45:00          -0.003537
# 2023-03-31 21:00:00           0.000599
# 2023-03-31 21:15:00           0.001890
# 2023-03-31 21:30:00           0.002138
# 2023-03-31 21:45:00          -0.001019
# 2023-03-31 22:00:00          -0.000049
# 2023-03-31 22:15:00           0.001594
# 2023-03-31 22:30:00           0.000509
# 2023-03-31 22:45:00          -0.000252
# 2023-03-31 23:00:00          -0.000843
# 2023-03-31 23:15:00           0.000038
# 2023-03-31 23:30:00          -0.001858
# 2023-03-31 23:45:00          -0.000450

# %%
raw_data = df[:20]["close"].values

# %%
raw_data
# Out:
# array([3695.6 , 3713.95, 3723.33, 3725.  , 3737.27, 3734.01, 3725.02,
#        3726.17, 3733.  , 3728.92, 3727.54, 3728.83, 3729.73, 3729.84,
#        3723.69, 3713.49, 3717.17, 3715.  , 3708.72, 3710.73])

# %%
from preprocess_data.domains.features_gen import Log_Price_Feature
log_price_feature = Log_Price_Feature(df["close"], 5, 0.02)
log_price_feature_value = log_price_feature.output_feature_array(normalize=True)

# %%
log_price_feature_value[:,0]
#Plot the histogram of log_price_feature_value with 1000 bin and fall under 99% percentile and title with plotlib
pd.Series(log_price_feature_value[:,0]).hist(bins=100, range=(pd.Series(log_price_feature_value[:,0]).quantile(0.0001), pd.Series(log_price_feature_value[:,0]).quantile(0.9999))).set_title("log_price_feature_value")
# Out:
# Text(0.5, 1.0, 'log_price_feature_value')
